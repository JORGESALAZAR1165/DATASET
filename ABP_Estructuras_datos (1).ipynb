# %% [markdown]
# # Taller: Lógica y estructuras de datos para el análisis
#
# **Duración estimada:** 30 minutos
# **Nivel:** Inicial
#
# ---
#
# ## 1. Contexto
#
# Eres analista en una empresa que recopila información sobre **ventas y satisfacción de clientes**.
# Tu tarea es procesar y analizar la información para generar pequeños reportes automatizados con Python, utilizando estructuras de datos y control de flujo.
#
# ---
#
# ## 2. Exploración de estructuras de datos
#
# ### 2.1 Ejercicio 1: Listas y Tuplas
#
# Crea las siguientes estructuras y responde las preguntas:
#
# **Datos iniciales:**
#
# - Lista de ventas (en millones):
#   `[10.5, 8.2, 9.7, 12.4, 7.9, 11.3]`
# - Tupla con nombres de los vendedores:
#   `("Ana", "Carlos", "Beatriz", "David", "Laura", "Santiago")`
#
# **Actividades:**
#
# 2.1.1. Muestra el total de ventas realizadas (puedes usar `sum()` o un bucle).
# 2.1.2. Calcula el promedio manualmente usando un ciclo `for`.
# 2.1.3. Identifica al vendedor con la **mayor venta**.
# 2.1.4. Agrega un nuevo valor de venta (13.1) y actualiza el total.
#
# ---
#
# ## 3. Diccionarios y condicionales
#
# ### 3.1 Ejercicio 2: Diccionarios y comprensión de datos
#
# Representa las ventas en un **diccionario** con la siguiente estructura:
#
# - "Ana": 10.5
# - "Carlos": 8.2
# - "Beatriz": 9.7
# - "David": 12.4
# - "Laura": 7.9
# - "Santiago": 11.3
#
# **Actividades:**
#
# 3.1.1. Recorre el diccionario e imprime un mensaje personalizado:
#    "Ana vendió 10.5 millones."
# 3.1.2. Crea una lista con los vendedores que superaron el promedio de ventas.
# 3.1.3. Usa una estructura condicional para clasificar cada venta:
#    - "Alta" si es mayor a 10
#    - "Media" si está entre 8 y 10
#    - "Baja" si es menor a 8
#
# ---
#
# ## 4. Aplicación práctica
#
# ### 4.1 Ejercicio 3: Pequeño reto de análisis
#
# Supón que recibes un conjunto de datos de satisfacción de clientes en una lista:
#
# `[4, 5, 3, 2, 4, 5, 5, 3, 4, 2, 1, 5, 4, 3]`
#
# **Actividades:**
#
# 4.1.1. Calcula el promedio de satisfacción.
# 4.1.2. Cuenta cuántos clientes dieron **calificación 5**.
# 4.1.3. Usa un bucle para crear un **nuevo diccionario** con el conteo de cada calificación (del 1 al 5).
# 4.1.4. Muestra un mensaje resumen:
#    "El promedio general fue de X y la mayoría calificó con Y."
#
# ---
#
# ## 5. Bonus (opcional)
#
# Representa las ventas en una **lista de diccionarios**, donde cada elemento contenga el nombre del vendedor y su venta, por ejemplo:
#
# - {"vendedor": "Ana", "venta": 10.5}
# - {"vendedor": "Carlos", "venta": 8.2}
# - {"vendedor": "Beatriz", "venta": 9.7}
# - {"vendedor": "David", "venta": 12.4}
# - {"vendedor": "Laura", "venta": 7.9}
# - {"vendedor": "Santiago", "venta": 11.3}
#
# **Actividad:**
#
# 5.1.1. Filtra con un bucle quiénes superaron el promedio y muestra su porcentaje de contribución al total de ventas.

# %%
import pandas as pd
import numpy as np

print ("creación de DataFrame")

data= {
    "Lista de ventas (en millones)": [10.5, 8.2, 9.7, 12.4, 7.9, 11.3],
    "Tupla con nombres de los vendedores": ["Ana", "Carlos", "Beatriz", "David", "Laura", "Santiago"]
}
df = pd.DataFrame(data)

display(df)
# Out:
# creación de DataFrame
#    Lista de ventas (en millones) Tupla con nombres de los vendedores
# 0                           10.5                                 Ana
# 1                            8.2                              Carlos
# 2                            9.7                             Beatriz
# 3                           12.4                               David
# 4                            7.9                               Laura
# 5                           11.3                            Santiago

# %%
# 2. EXPLORACIÓN DE ESTRUCTURAS DE DATOS #

Lista_ventas_millones = [10.5, 8.2, 9.7, 12.4, 7.9, 11.3]
Tupla_nombres_vendedores = ("Ana", "Carlos", "Beatriz", "David", "Laura", "Santiago")

Total_ventas = sum(Lista_ventas_millones)
print("El total de ventas es: ", Total_ventas)

for venta in Lista_ventas_millones:
    Promedio_ventas = sum(Lista_ventas_millones) / len(Lista_ventas_millones)
print("El promedio de ventas es: ", Promedio_ventas)

max_venta = max(Lista_ventas_millones)
print("El vendedor con la mayor venta es: ", max_venta)

Lista_ventas_millones.append(13.1)
Total_ventas = sum(Lista_ventas_millones)
print("El total de ventas es: ", Total_ventas)
# Out:
# El total de ventas es:  60.0
# El promedio de ventas es:  10.0
# El vendedor con la mayor venta es:  12.4
# El total de ventas es:  73.1

# %%
# 3. DICCIONARIOS Y CONDICIONALES #

diccionario_ventas = {"Ana": 10.5, "Carlos": 8.2, "Beatriz": 9.7, "David": 12.4, "Laura": 7.9, "Santiago": 11.3}

for vendedor, venta in diccionario_ventas.items():
    print(f"{vendedor} vendió {venta} millones.")
# Out:
# Ana vendió 10.5 millones.
# Carlos vendió 8.2 millones.
# Beatriz vendió 9.7 millones.
# David vendió 12.4 millones.
# Laura vendió 7.9 millones.
# Santiago vendió 11.3 millones.
